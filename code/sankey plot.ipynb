# %% [raw]
# ---
# title: "Refugee Crisis in Europe in the 21st Century"
# author:
#   - name: Jingda Yang, Wendi Chu, Haiyu Xiao, Tingsong Li
#
# execute:
#     echo: false
# output:
#     html_document:
#         smooth-scroll: true
#     highlight: zenburn
#     toc: true
#     toc_depth: 2
#     margin-left: 5in
#     margin-right: 5in
#     pdf_document:
#         toc: true
# format:
#   html:
#     theme: united
#     embed-resources: true
#     code-fold: true
#     page-layout: full
# #reference-location: margin
# #citation-location: margin
# #bibliography: skeleton.bib
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pycountry_convert as pc
from pyecharts.charts import  Sankey
from pyecharts import options as opts
import warnings
warnings.filterwarnings("ignore")

# %%
popu=pd.read_csv("../data/population.csv")

popu1=popu.loc[:,["Year","Country of origin (ISO)","Country of asylum (ISO)","Refugees under UNHCR's mandate"]]

popu1.columns=["year","Origin_ISO","Asylum_ISO","Number"]

# only keep observations after 2002
popu1=popu1[popu1.year>=2002]

# delete rows with missing values
popu1=popu1[-pd.isna(popu1.Origin_ISO)]
popu1=popu1[-pd.isna(popu1.Asylum_ISO)]

# delete rows of domestic refugee movement
popu1=popu1[popu1.Origin_ISO!=popu1.Asylum_ISO]

# delete rows with meaningless value
popu1=popu1[popu1.Number!=0]

# %%
popu1=popu1.reset_index().iloc[:,1:5]
popu1.head()
# Out:
#    year Origin_ISO Asylum_ISO  Number
# 0  2002        IRQ        ALB       5
# 1  2002        SRB        ALB       6
# 2  2002        TUR        ALB       7
# 3  2002        CMR        DZA       6
# 4  2002        PSE        DZA    4005

# %%
# define a function to get continent name for each country

def country_to_continent(country_alpha3):
    country_alpha2 = pc.country_alpha3_to_country_alpha2(country_alpha3)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name

# %%
origin_continent=[]
asylum_continent=[]
for i in range(len(popu1)):
    try:
        origin_continent.append(country_to_continent(popu1.Origin_ISO[i]))
    except:
        origin_continent.append('')
    try:
        asylum_continent.append(country_to_continent(popu1.Asylum_ISO[i]))
    except:
        asylum_continent.append('')

# %%
# add columns that display continents of origin and asylum country 
popu1["Origin_continent"]=origin_continent
popu1["Asylum_continent"]=asylum_continent

# %%
popu1=popu1[popu1.Origin_continent!='']
popu1=popu1[popu1.Asylum_continent!='']
popu1.head()
# Out:
#    year Origin_ISO Asylum_ISO  Number Origin_continent Asylum_continent
# 0  2002        IRQ        ALB       5             Asia           Europe
# 1  2002        SRB        ALB       6           Europe           Europe
# 2  2002        TUR        ALB       7             Asia           Europe
# 3  2002        CMR        DZA       6           Africa           Africa
# 4  2002        PSE        DZA    4005             Asia           Africa

# %%
# group the data by origin and asylum continent
df_grouped=popu1.groupby(['Origin_continent','Asylum_continent']).sum().iloc[:,1]
print(df_grouped)
# Out:
# Origin_continent  Asylum_continent
# Africa            Africa               84061708
#                   Asia                  4097435
#                   Europe                8192838
#                   North America         2351434
#                   Oceania                192007
#                   South America           79495
# Asia              Africa                3855792
#                   Asia                139136469
#                   Europe               22189323
#                   North America         3912121
#                   Oceania                877000
#                   South America           81297
# Europe            Africa                   1704
#                   Asia                   165855
#                   Europe               14604476
#                   North America         1363642
#                   Oceania                 57619
#                   South America           11267
# North America     Africa                     59
#                   Asia                       62
#                   Europe                 178064
#                   North America         1782677
#                   Oceania                   909
#                   South America           36185
# Oceania           Africa                     79
#                   Asia                       25
#                   Europe                   1316
#                   North America           19755
#                   Oceania                 10348
# South America     Africa                      6
#                   Asia                       29
#                   Europe                 446962
#                   North America         1221161
#                   Oceania                  5392
#                   South America         4410890
# Name: Number, dtype: int64

# %%
# create nodes for the sankey plot
nodes=[{'name':'Europe(from)'},{'name':'Africa(from)'},{'name':'Asia(from)'},
       {'name':'North America(from)'},{'name':'South America(from)'},{'name':'Oceania(from)'},
       {'name':'Europe(to)'},{'name':'Africa(to)'},{'name':'Asia(to)'},
       {'name':'North America(to)'},{'name':'South America(to)'},{'name':'Oceania(to)'}]

# %%
# create linkes for the sankey plot of global refugee movement
linkes_all=[]
for i in range(35):
    dic={}
    dic['source']=df_grouped.index[i][0]+"(from)"
    dic['target']=df_grouped.index[i][1]+"(to)"
    dic['value']=df_grouped[i]
    linkes_all.append(dic)

linkes_all.append({'source':'Oceania(from)','target':'South America(to)','value':0})
len(linkes_all)
# Out:
# 36

# %%
# Read the txt files which contain the linkes for the sankey plot of refugee flow

from pathlib import Path
txt1 = Path('./Sankey_plot_linkes/linkes_all.txt').read_text()
txt1=txt1.replace("\n","")
linkes_all=eval(txt1)

txt2 = Path('./Sankey_plot_linkes/linkes_eu.txt').read_text()
txt2=txt2.replace("\n","")
linkes_eu=eval(txt2)

# %%
# | label: fig-map1
# | fig-cap: Sankey plot of global refugee flow within past two decades. The nodes on the left side represent for the original continents of refugees, while nodes on the right side represent for the continents of asylum countries.
pic_all=(
    Sankey().add(
        '',
        nodes,
        linkes_all,
        # set the opacity, shape and color
        linestyle_opt=opts.LineStyleOpts(opacity=0.3,curve=0.5,color='gradient'),
        # set the labels
        label_opts=opts.LabelOpts(position='right'),
        # set the gap between nodes
        node_gap=10,
    )
    .set_global_opts(title_opts=opts.TitleOpts(title='Sankey Plot of Global Refugee Movement',pos_left = '20%'))
)
pic_all.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a861f0b35035469da16e8cb196147c6c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a861f0b35035469da16e8cb196147c6c = echarts.init(
#                     document.getElementById('a861f0b35035469da16e8cb196147c6c'), 'white', {renderer: 'canvas'});
#                 var option_a861f0b35035469da16e8cb196147c6c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "data": [
#                 {
#                     "name": "Europe(from)"
#                 },
#                 {
#                     "name": "Africa(from)"
#                 },
#                 {
#                     "name": "Asia(from)"
#                 },
#                 {
#                     "name": "North America(from)"
#                 },
#                 {
#                     "name": "South America(from)"
#                 },
#                 {
#                     "name": "Oceania(from)"
#                 },
#                 {
#                     "name": "Europe(to)"
#                 },
#                 {
#                     "name": "Africa(to)"
#                 },
#                 {
#                     "name": "Asia(to)"
#                 },
#                 {
#                     "name": "North America(to)"
#                 },
#                 {
#                     "name": "South America(to)"
#                 },
#                 {
#                     "name": "Oceania(to)"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "Africa(from)",
#                     "target": "Africa(to)",
#                     "value": 84061708
#                 },
#                 {
#                     "source": "Africa(from)",
#                     "target": "Asia(to)",
#                     "value": 4097435
#                 },
#                 {
#                     "source": "Africa(from)",
#                     "target": "Europe(to)",
#                     "value": 8192838
#                 },
#                 {
#                     "source": "Africa(from)",
#                     "target": "North America(to)",
#                     "value": 2351434
#                 },
#                 {
#                     "source": "Africa(from)",
#                     "target": "Oceania(to)",
#                     "value": 192007
#                 },
#                 {
#                     "source": "Africa(from)",
#                     "target": "South America(to)",
#                     "value": 79495
#                 },
#                 {
#                     "source": "Asia(from)",
#                     "target": "Africa(to)",
#                     "value": 3855792
#                 },
#                 {
#                     "source": "Asia(from)",
#                     "target": "Asia(to)",
#                     "value": 139136469
#                 },
#                 {
#                     "source": "Asia(from)",
#                     "target": "Europe(to)",
#                     "value": 22189323
#                 },
#                 {
#                     "source": "Asia(from)",
#                     "target": "North America(to)",
#                     "value": 3912121
#                 },
#                 {
#                     "source": "Asia(from)",
#                     "target": "Oceania(to)",
#                     "value": 877000
#                 },
#                 {
#                     "source": "Asia(from)",
#                     "target": "South America(to)",
#                     "value": 81297
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "Africa(to)",
#                     "value": 1704
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "Asia(to)",
#                     "value": 165855
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "Europe(to)",
#                     "value": 14604476
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "North America(to)",
#                     "value": 1363642
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "Oceania(to)",
#                     "value": 57619
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "South America(to)",
#                     "value": 11267
#                 },
#                 {
#                     "source": "North America(from)",
#                     "target": "Africa(to)",
#                     "value": 59
#                 },
#                 {
#                     "source": "North America(from)",
#                     "target": "Asia(to)",
#                     "value": 62
#                 },
#                 {
#                     "source": "North America(from)",
#                     "target": "Europe(to)",
#                     "value": 178064
#                 },
#                 {
#                     "source": "North America(from)",
#                     "target": "North America(to)",
#                     "value": 1782677
#                 },
#                 {
#                     "source": "North America(from)",
#                     "target": "Oceania(to)",
#                     "value": 909
#                 },
#                 {
#                     "source": "North America(from)",
#                     "target": "South America(to)",
#                     "value": 36185
#                 },
#                 {
#                     "source": "Oceania(from)",
#                     "target": "Africa(to)",
#                     "value": 79
#                 },
#                 {
#                     "source": "Oceania(from)",
#                     "target": "Asia(to)",
#                     "value": 25
#                 },
#                 {
#                     "source": "Oceania(from)",
#                     "target": "Europe(to)",
#                     "value": 1316
#                 },
#                 {
#                     "source": "Oceania(from)",
#                     "target": "North America(to)",
#                     "value": 19755
#                 },
#                 {
#                     "source": "Oceania(from)",
#                     "target": "Oceania(to)",
#                     "value": 10348
#                 },
#                 {
#                     "source": "South America(from)",
#                     "target": "Africa(to)",
#                     "value": 6
#                 },
#                 {
#                     "source": "South America(from)",
#                     "target": "Asia(to)",
#                     "value": 29
#                 },
#                 {
#                     "source": "South America(from)",
#                     "target": "Europe(to)",
#                     "value": 446962
#                 },
#                 {
#                     "source": "South America(from)",
#                     "target": "North America(to)",
#                     "value": 1221161
#                 },
#                 {
#                     "source": "South America(from)",
#                     "target": "Oceania(to)",
#                     "value": 5392
#                 },
#                 {
#                     "source": "South America(from)",
#                     "target": "South America(to)",
#                     "value": 4410890
#                 },
#                 {

# %% [markdown]
# According to this sankey plot of global refugee movement, we can clearly observe that Africa, Asia and Europe have most refugee inflows and outflows in past 20 years. Also, this graph tells us that the vast majority of refugees in Asia and Africa move only within continents. However, more than half of refugees who move towards Europe come from other continents. Taking into consideration for both high proportion of refugees arriving from other continents and recent local conflict in Europe that may cause significant fluctuation of refugee movement, we will mainly focus on refugees from and to Europe in subsequent analysis.

# %%
# | label: fig-map2
# | fig-cap: Sankey plot of refugees from and towards Europe within past two decades. The nodes on the left side represent for the original continents of refugees, while nodes on the right side represent for the continents of asylum countries.
pic_eu=(
    Sankey().add(
        '',
        nodes,
        linkes_eu,
        # set the opacity, shape and color
        linestyle_opt=opts.LineStyleOpts(opacity=0.5,curve=0.5,color='gradient'),
        # set the labels
        label_opts=opts.LabelOpts(position='right'),
        # set the gap between nodes
        node_gap=12,
    )
    .set_global_opts(title_opts=opts.TitleOpts(title='Refugees from and to Europe',pos_left = '25%'))
)
pic_eu.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3b042b4a2228455abe1b516a75ae59f9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3b042b4a2228455abe1b516a75ae59f9 = echarts.init(
#                     document.getElementById('3b042b4a2228455abe1b516a75ae59f9'), 'white', {renderer: 'canvas'});
#                 var option_3b042b4a2228455abe1b516a75ae59f9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "data": [
#                 {
#                     "name": "Europe(from)"
#                 },
#                 {
#                     "name": "Africa(from)"
#                 },
#                 {
#                     "name": "Asia(from)"
#                 },
#                 {
#                     "name": "North America(from)"
#                 },
#                 {
#                     "name": "South America(from)"
#                 },
#                 {
#                     "name": "Oceania(from)"
#                 },
#                 {
#                     "name": "Europe(to)"
#                 },
#                 {
#                     "name": "Africa(to)"
#                 },
#                 {
#                     "name": "Asia(to)"
#                 },
#                 {
#                     "name": "North America(to)"
#                 },
#                 {
#                     "name": "South America(to)"
#                 },
#                 {
#                     "name": "Oceania(to)"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "Europe(from)",
#                     "target": "Europe(to)",
#                     "value": 14604476
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "Asia(to)",
#                     "value": 165855
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "Africa(to)",
#                     "value": 1704
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "North America(to)",
#                     "value": 1363642
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "South America(to)",
#                     "value": 11267
#                 },
#                 {
#                     "source": "Europe(from)",
#                     "target": "Oceania(to)",
#                     "value": 57619
#                 },
#                 {
#                     "source": "Asia(from)",
#                     "target": "Europe(to)",
#                     "value": 22189323
#                 },
#                 {
#                     "source": "Africa(from)",
#                     "target": "Europe(to)",
#                     "value": 8192838
#                 },
#                 {
#                     "source": "North America(from)",
#                     "target": "Europe(to)",
#                     "value": 178064
#                 },
#                 {
#                     "source": "South America(from)",
#                     "target": "Europe(to)",
#                     "value": 446962
#                 },
#                 {
#                     "source": "Oceania(from)",
#                     "target": "Europe(to)",
#                     "value": 1316
#                 }
#             ],
#             "left": "5%",
#             "top": "5%",
#             "right": "20%",
#             "bottom": "5%",
#             "nodeWidth": 20,
#             "nodeGap": 12,
#             "nodeAlign": "justify",
#             "layoutIteration": 32,
#             "orient": "horizontal",
#             "draggable": true,
#             "emphasis": {
#                 "focus": "none"
#             },
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 0.5,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "gradient"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Refugees from and to Europe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "25%",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_3b042b4a2228455abe1b516a75ae59f9.setOption(option_3b042b4a2228455abe1b516a75ae59f9);
#         });
#     </script>

# %% [markdown]
# Unlike the former plot of global refugee flows, this graph only display refugees from and to Europe since 2002. From this plot, we notice that most of refugees that origin from Europe move to other European countries and a considerable number of refugees move to North America. By contrast, for the refugees move to Europe, almost half are from Asia, followed by Europe and Africa.
